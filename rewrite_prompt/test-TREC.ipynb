# %% [markdown]
# # API-info

# %%
from openai import OpenAI
import httpx
client = OpenAI(
    base_url="https://api.xiaoai.plus/v1",
    api_key="sk-gjmt4deRRB00reuN10Af64DdBeDd4a8e8b45Fb58Bd57A631",
    http_client=httpx.Client(
        base_url="https://api.xiaoai.plus/v1",
        follow_redirects=True,
    ),
)

# %% [markdown]
# # Zero-shot

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    #temperature = 0,
    messages = [
        {"role": "user", "content": (
            "You will be provided with a question."
            "Your task is to rewrite the given question without changing its meaning."
            
            "Output format:"
            "You should output only the rewritten question in one line."
        )},
        {"role": "user", "content": 
            "Question you should rewrite: What films featured the character Popeye Doyle ?"
        }
    ]
)

print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File E:\Environments\conda\envs\pytorch-gpu-env\lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File E:\Environments\conda\envs\pytorch-gpu-env\lib\site-packages\httpcore\_backends\sync.py:168, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     167         self.close()
# --> 168         raise exc
#     169 return SyncStream(sock)
#
# File E:\Environments\conda\envs\pytorch-gpu-env\lib\site-packages\httpcore\_backends\sync.py:163, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     162         self._sock.settimeout(timeout)
# --> 163         sock = ssl_context.wrap_socket(
#     164             self._sock, server_hostname=server_hostname
#     165         )
# ...

# %% [markdown]
# # Other prompts

# %% [markdown]
# # 测试总结
